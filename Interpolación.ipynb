# %% [markdown]
# <a href="https://colab.research.google.com/github/pedromirsky/Calculo-Numerico/blob/main/Interpolaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x1 =np.linspace(0,10,2)

y1 = 3*x1+4

plt.scatter(x1, y1, marker='^');

# %%
x1 =np.linspace(0,10,2)

y1 = 3*x1+4

plt.scatter(x1, y1, marker='^');
plt.plot(x1, y1, 'r');

# %%
x2 =np.linspace(-10,10,3)

y2 = x2**2  +2

plt.scatter(x2, y2, marker='^');

plt.show()

# %%
x2 =np.linspace(-10,10,3)
x3 =np.linspace(-10,10,5)
x4 =np.linspace(-10,10,416)
y2 = x2**2  +2

plt.scatter(x2, y2, marker='^');
plt.plot(x2, y2, 'r');
#plt.plot(x3, (x3**2+2), 'b');
plt.plot(x4, (x4**2+2), 'g');

plt.scatter(5, 27.3, s=35);

plt.show()

# %%
x1 =np.linspace(0,10,2)

y1 = 3*x1+4

plt.scatter(x1, y1, marker='^');
plt.plot(x1, y1, 'r');
plt.xticks([])
plt.yticks([])
# Out:
# ([], <a list of 0 Text major ticklabel objects>)

# %% [markdown]
# ![](https://tricolor-scilla-68c.notion.site/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2F476bb03c-bd39-4e73-aaef-3ece2b3255b1%2FUntitled.png?table=block&id=e25e5119-cb00-4979-8dd7-f1decdab8226&spaceId=62aa27de-48fd-4703-8a40-2de64b627b11&width=2000&userId=&cache=v2)

# %%
import sympy as sp
x = sp.symbols('x')

# %%
x0 = 2
x1 = 5
y0 = 4
y1 = 1

y = ( (x-x1)  /  (x0-x1) ) * y0 + ( (x-x0)  /  (x1-x0) ) * y1
y # Pol Interpolación de Lagrange
# Out:
# 6 - x

# %%
## Ejercicio 1 --> grafico el polinomio de interpolación obtenido
x =np.linspace(2,5,2)

y = -x+6

plt.scatter(x, y, marker='^');
plt.plot(x, y, 'r');

# %% [markdown]
# ![](https://tricolor-scilla-68c.notion.site/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2Faf6ff886-19be-46dc-bcd3-ce659fa0ce63%2FUntitled.png?table=block&id=f7e860ea-1fbc-49ac-a4e2-09262babd09f&spaceId=62aa27de-48fd-4703-8a40-2de64b627b11&width=2000&userId=&cache=v2)

# %%
import sympy as sp
x = sp.sympify('x')
f = 1/x

x0 = 2
x1 = 2.75
x2 = 4

y0 = f.subs(x,x0)
y1 = f.subs(x,x1)
y2 = f.subs(x,x2)

# %%
L0 =  ( (x-x1)  /  (x0-x1) ) *  ( (x-x2)  /  (x0-x2) )

# %%
L1 =  ( (x-x0)  /  (x1-x0) ) * ( (x-x2)  /  (x1-x2) )

# %%
L2 =  ( (x-x0)  /  (x2-x0) ) * ( (x-x1)  /  (x2-x1) )

# %%
pn = L0 * y0 + L1 * y1 + L2 * y2

pn = sp.simplify(pn)
pn
# Out:
# 0.0454545454545455*x**2 - 0.397727272727272*x + 1.11363636363636

# %% [markdown]
# ![](https://tricolor-scilla-68c.notion.site/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2Fa0a50599-91f3-46e0-b591-90b069e3ed75%2FUntitled.png?table=block&id=506380e6-cf8f-4691-8be4-b93b5f47a8f5&spaceId=62aa27de-48fd-4703-8a40-2de64b627b11&width=2000&userId=&cache=v2)

# %% [markdown]
# ## Veamos la parte de f(3)

# %%
# veo el error en la interpolación hallada. (comparo la y para un valor x=3 en f = 1/x y mi pn hallada)
pn.subs(x,3) - f.subs(x,3)
# Out:
# -0.00378787878787784

# %% [markdown]
# ## Plot

# %%
p = sp.plot(f, pn, xlim =[0, 3], ylim = [0, 10], show = False);
p[1].line_color = "r"
p.show()

# %% [markdown]
# La interpolación hallada aproxima la función únicamente dentro del intervalo que comprende los puntos que yo tengo. Como los x usados fueron :
#
# x0 = 2
#
# x1 = 2.75
#
# x2 = 4
#
# Entonces, mi aproximación de la función es para x entre 2 y 4

# %% [markdown]
# ## Pensemos como armar el código

# %% [markdown]
# ![](https://tricolor-scilla-68c.notion.site/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2Fa0a50599-91f3-46e0-b591-90b069e3ed75%2FUntitled.png?table=block&id=506380e6-cf8f-4691-8be4-b93b5f47a8f5&spaceId=62aa27de-48fd-4703-8a40-2de64b627b11&width=2000&userId=&cache=v2)

# %% [markdown]
# # Vamos al caso de grado 1
#
# ![](https://tricolor-scilla-68c.notion.site/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2F3e2c20a8-3870-462f-b91d-eadee37e0757%2FUntitled.png?table=block&id=cc5598d1-0585-42d3-a420-a8dbd4d7756d&spaceId=62aa27de-48fd-4703-8a40-2de64b627b11&width=2000&userId=&cache=v2)

# %% [markdown]
# ![](https://tricolor-scilla-68c.notion.site/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2Faf6ff886-19be-46dc-bcd3-ce659fa0ce63%2FUntitled.png?table=block&id=f7e860ea-1fbc-49ac-a4e2-09262babd09f&spaceId=62aa27de-48fd-4703-8a40-2de64b627b11&width=2000&userId=&cache=v2)

# %%
# primero guardo los valores obtenidos en vectores 
# Lk = [L0, L1, L2]

x = sp.sympify('x')
f = 1/x

x0 = 2
x1 = 2.75
x2 = 4

y0 = f.subs(x,x0)
y1 = f.subs(x,x1)
y2 = f.subs(x,x2)

Y = [y0, y1, y2]
X = [x0, x1, x2]


Pn = 0



for k in range (len(Y)):
  productoria = 1

  for i in range (len(Y)):

    if i != k:

      factor = ( ( x-X[i] ) / (X[k] - X[i]) )


      productoria = productoria * factor 
      
      #termino =  (Y[k] * ( ( x-X[i] ) / (X[k] - X[i]) ))
      #Pn = Pn + termino

  termino =  Y[k] * productoria
  Pn = Pn + termino
  
Pn = sp.simplify(Pn)
Pn
# Out:
# 0.0454545454545455*x**2 - 0.397727272727272*x + 1.11363636363636

# %%
# Out:
# 0
# 1
# 2
