# %% [markdown]
# <a href="https://colab.research.google.com/github/pedromirsky/Calculo-Numerico/blob/main/Punto_Fijo_Metodo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-1.0, 3.0, num=50)
f = np.exp(-x)-x
f1 = np.exp(-x)
f2 = x

fig, (ax1, ax2) = plt.subplots(2, 1)
fig.suptitle('método punto fijo')

ax1.plot(x, f, 'o-')
ax1.set_ylabel('f')
ax1.axhline(y=0, color='k', linestyle='-')

ax2.plot(x, f1, '.-', label="e-x")
ax2.plot(x, f2, '.-', label="x")
ax2.set_xlabel('x')
ax2.set_ylabel('f')

plt.legend()
plt.show()

# %%
def funcionG(x):
  return np.exp(-x)

# %%
funcionG(0)
# Out:
# 1.0

# %%
funcionG(1)
# Out:
# 0.36787944117144233

# %%
funcionG(0.36787944117144233)
# Out:
# 0.6922006275553464

# %%
funcionG(0.6922006275553464)
# Out:
# 0.5004735005636368

# %%
funcionG(0.5004735005636368)
# Out:
# 0.6062435350855974

# %%
funcionG(0.6062435350855974)
# Out:
# 0.545395785975027

# %%
funcionG(0.545395785975027)
# Out:
# 0.5796123355033789

# %%
funcionG(0.5796123355033789)
# Out:
# 0.5601154613610891

# %%
funcionG(0.5601154613610891)
# Out:
# 0.571143115080177

# %%
funcionG(0.571143115080177)
# Out:
# 0.5648793473910495

# %%
def funcionG2(x):
  return x**2 - 4 + x

# %%
from sympy import *
import pandas as pd

iteracionMax= 20
p0 = 0
tol = 0.000000001

x = symbols('x')
f1 = x**2 - 4 + x

valores_p = []
valores_p0 = []
valores_e = []

datos = {
    "p" : valores_p,
    "p0": valores_p0,
    'e' : valores_e
    }


for i in range(iteracionMax):

  
 
  p = f1.subs(x,p0)
  valores_p.append(p)
  valores_p0.append(p0)
  valores_e.append(abs(p-p0))

  print(p)

  if abs(p-p0) < tol:
    print(p)
    break;
  else: 
    p0 = p
   

df = pd.DataFrame(datos)
df=df.astype(float) 
df.head(10)
# Out:
# -4
# 8
# 68
# 4688
# 21982028
# 483209576974808
# 233491495280173380882643611668
# 54518278368171228201482876236565907627201914279213829353888
# 2972242676229406876929820193197767805256555494255023229098871798457918795124536378254006408755863587640367373370070428
# 8834226526399346795610010385640634425835781054007005533458131011411830454025986266391509852278374554331121766907120840498013391823437717692626415137149867457003669246552190869411058145847352281416163577221453934157244384010783050173608
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
#                p             p0              e
# 0  -4.000000e+00   0.000000e+00   4.000000e+00
# 1   8.000000e+00  -4.000000e+00   1.200000e+01
# 2   6.800000e+01   8.000000e+00   6.000000e+01
# 3   4.688000e+03   6.800000e+01   4.620000e+03
# 4   2.198203e+07   4.688000e+03   2.197734e+07
# 5   4.832096e+14   2.198203e+07   4.832096e+14
# 6   2.334915e+29   4.832096e+14   2.334915e+29
# ...

# %%
def puntoFijo(p0 = 0,f,iteracionMax = 10000, tol = 0):
     iteracionMax = 100
     contador_ iteraciones = 0

     while i <= iteracionMax:
       p = g


for i in range(N):
 
  p = funcionG2(p0)
  print(p)

  if abs(p-p0) < tol:
    print(p)
    break;
  else: 
    p0 = p

# %%
from sympy import *
import pandas as pd

f1 = x**2 - 4 + x

def puntoFijo (f, p0 = 0, iteracionMax = 10000, tol = 0):
    x = symbols('x')
    valores_p = []
    valores_p0 = []
    valores_e = []

    datos = {
        "p" : valores_p,
        "p0": valores_p0,
        'e' : valores_e
        }


    for i in range(iteracionMax):
    
      p = f1.subs(x,p0)
      valores_p.append(p)
      valores_p0.append(p0)
      valores_e.append(abs(p-p0))

      print(p)

      if abs(p-p0) < tol:
        print(p)
        break;
      else: 
        p0 = p

    df = pd.DataFrame(datos)
    df=df.astype(float) 
    df.head(10)
    df['e'].plot() 

puntoFijo(f1, p0 = 0, iteracionMax= 20)
#puntoFijo(f2, p0 = 0, iteracionMax= 20)
#puntoFijo(f3, p0 = 0, iteracionMax= 20)
#puntoFijo(f4, p0 = 0, iteracionMax= 20)
# Out:
# -4
# 8
# 68
# 4688
# 21982028
# 483209576974808
# 233491495280173380882643611668
# 54518278368171228201482876236565907627201914279213829353888
# 2972242676229406876929820193197767805256555494255023229098871798457918795124536378254006408755863587640367373370070428
# 8834226526399346795610010385640634425835781054007005533458131011411830454025986266391509852278374554331121766907120840498013391823437717692626415137149867457003669246552190869411058145847352281416163577221453934157244384010783050173608
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
